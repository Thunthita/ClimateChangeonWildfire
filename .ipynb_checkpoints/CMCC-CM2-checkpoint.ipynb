# %%
import xarray as xr
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import linregress

# Define file paths for different scenarios
files_historical1 = 'D:\Jubjang/FWICMIP6/fwisa_ann_CMCC-CM2-SR5_historical_r1i1p1f1_g025.nc'
files_historical2 = [f'D:/Jubjang/FWICMIP6/fwisa_ann_CMCC-CM2-SR5_historical_r{i}i1p2f1_g025.nc' for i in range(2, 12)]
files_SSP126 = 'D:/Jubjang/FWICMIP6/fwisa_ann_CMCC-CM2-SR5_ssp126_r1i1p1f1_g025.nc'
files_SSP245 = 'D:/Jubjang/FWICMIP6/fwisa_ann_CMCC-CM2-SR5_ssp245_r1i1p1f1_g025.nc'
files_SSP370 = 'D:/Jubjang/FWICMIP6/fwisa_ann_CMCC-CM2-SR5_ssp370_r1i1p1f1_g025.nc'
files_SSP585 = 'D:/Jubjang/FWICMIP6/fwisa_ann_CMCC-CM2-SR5_ssp585_r1i1p1f1_g025.nc'


# Load datasets
datasets_historical1 = xr.open_mfdataset(files_historical1)
datasets_historical2 = [xr.open_dataset(f) for f in files_historical2] 
datasets_SSP126 = xr.open_mfdataset(files_SSP126, combine='by_coords', engine='netcdf4')
datasets_SSP245 = xr.open_mfdataset(files_SSP245, combine='by_coords', engine='netcdf4')
dataset_SSP370 = xr.open_mfdataset(files_SSP370, combine='by_coords', engine='netcdf4')
datasets_SSP585 = xr.open_mfdataset(files_SSP585, combine='by_coords', engine='netcdf4')

print("Datasets successfully loaded!")
# Out:
# Datasets successfully loaded!

# %%
datasets_historical2_combined = xr.concat(datasets_historical2, dim="time")  # Combine list into one dataset
historical_combined = xr.concat([datasets_historical1, datasets_historical2_combined], dim="time")

print(historical_combined)
# Out:
# <xarray.Dataset>
# Dimensions:  (lon: 144, lat: 72, time: 1815)
# Coordinates:
#   * lon      (lon) float64 1.25 3.75 6.25 8.75 11.25 ... 351.2 353.8 356.2 358.8
#   * lat      (lat) float64 -88.75 -86.25 -83.75 -81.25 ... 83.75 86.25 88.75
#   * time     (time) object 1850-07-01 06:00:00 ... 2014-07-01 06:00:00
# Data variables:
#     fwisa    (time, lat, lon) float64 dask.array<chunksize=(165, 72, 144), meta=np.ndarray>
# Attributes: (12/18)
#     CDI:                       Climate Data Interface version 1.9.9 (https://...
#     Conventions:               CF-1.6
#     experiment_id:             historical
#     table_id:                  ann
#     source_id:                 CMCC-CM2-SR5
#     variant_label:             r1i1p1f1
#     ...                        ...
#     warning_method_init:       The FWI has been initialized by the common way...
#     cmip6-ng:                  \ncontact = cmip6-archive@env.ethz.ch\ndescrip...
# ...
